# %% [markdown]
# <a href="https://colab.research.google.com/github/sese11225/Class-201-/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from numpy. random import random
np.random.seed(123)
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
missing_values =['?']
df = df.replace(missing_values,np.NAN)

# %%
df.head()
df
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
df['diabetesMed'].max()
df
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  ...  number_inpatient  number_diagnoses
# count  1.017660e+05  1.017660e+05  ...     101766.000000     101766.000000
# mean   1.652016e+08  5.433040e+07  ...          0.635566          7.422607
# std    1.026403e+08  3.869636e+07  ...          1.262863          1.933600
# min    1.252200e+04  1.350000e+02  ...          0.000000          1.000000
# 25%    8.496119e+07  2.341322e+07  ...          0.000000          6.000000
# 50%    1.523890e+08  4.550514e+07  ...          0.000000          8.000000
# 75%    2.302709e+08  8.754595e+07  ...          1.000000          9.000000
# max    4.438672e+08  1.895026e+08  ...         21.000000         16.000000
#
# [8 rows x 13 columns]

# %%
df[['race','admission_type_id']]
# Out:
#                    race  admission_type_id
# 0             Caucasian                  6
# 1             Caucasian                  1
# 2       AfricanAmerican                  1
# 3             Caucasian                  1
# 4             Caucasian                  1
# ...                 ...                ...
# 101761  AfricanAmerican                  1
# 101762  AfricanAmerican                  1
# 101763        Caucasian                  1
# 101764        Caucasian                  2
# 101765        Caucasian                  1
#
# [101766 rows x 2 columns]

# %%
df[['admission_type_id','time_in_hospital']]
# Out:
#         admission_type_id  time_in_hospital
# 0                       6                 1
# 1                       1                 3
# 2                       1                 2
# 3                       1                 2
# 4                       1                 1
# ...                   ...               ...
# 101761                  1                 3
# 101762                  1                 5
# 101763                  1                 1
# 101764                  2                10
# 101765                  1                 6
#
# [101766 rows x 2 columns]

# %%
df['time_in_hospital'].describe()
# Out:
# count    101766.000000
# mean          4.395987
# std           2.985108
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%           6.000000
# max          14.000000
# Name: time_in_hospital, dtype: float64

# %%
df['admission_type_id'].describe()
# Out:
# count    101766.000000
# mean          2.024006
# std           1.445403
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           3.000000
# max           8.000000
# Name: admission_type_id, dtype: float64

# %%
df.rename(columns={'admission_type_id':'AtI','time_in_hospital':'TiH'})
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
# find admission type & time in hospital and describe
df['source']=df['admission_type_id']+df['time_in_hospital']
df
# Out:
#         encounter_id  patient_nbr  ... readmitted source
# 0            2278392      8222157  ...         NO      7
# 1             149190     55629189  ...        >30      4
# 2              64410     86047875  ...         NO      3
# 3             500364     82442376  ...         NO      3
# 4              16680     42519267  ...         NO      2
# ...              ...          ...  ...        ...    ...
# 101761     443847548    100162476  ...        >30      4
# 101762     443847782     74694222  ...         NO      6
# 101763     443854148     41088789  ...         NO      2
# 101764     443857166     31693671  ...         NO     12
# 101765     443867222    175429310  ...         NO      7
#
# [101766 rows x 51 columns]

# %%
df['source'].describe()
# Out:
# count    101766.000000
# mean          6.419993
# std           3.300332
# min           2.000000
# 25%           4.000000
# 50%           6.000000
# 75%           8.000000
# max          22.000000
# Name: source, dtype: float64

# %%
df[df['time_in_hospital']>10]
# Out:
#         encounter_id  patient_nbr  ... readmitted source
# 8              12522     48330783  ...         NO     15
# 9              15738     63555939  ...         NO     15
# 15             73578     86328819  ...         NO     13
# 23            183930    107400762  ...        >30     13
# 42            421194     96435585  ...        >30     15
# ...              ...          ...  ...        ...    ...
# 101725     443699066     14701734  ...         NO     13
# 101748     443811536    189481478  ...        >30     15
# 101751     443835140    175326800  ...         NO     16
# 101753     443841992    184875899  ...         NO     14
# 101755     443842022    188574944  ...        >30     15
#
# [5555 rows x 51 columns]

# %%
df[df['admission_type_id']>5]
# Out:
#         encounter_id  patient_nbr  ... readmitted source
# 0            2278392      8222157  ...         NO      7
# 117          1968528       720936  ...        >30     16
# 118          2040360       661014  ...         NO     15
# 121          2088630      1719279  ...        >30     17
# 122          2091690      7919802  ...         NO     12
# ...              ...          ...  ...        ...    ...
# 101521     440285876     87851016  ...         NO      8
# 101542     440811614     21036033  ...         NO     10
# 101615     441960572    105626313  ...         NO     11
# 101692     443138246     55146366  ...         NO     10
# 101724     443698988    105807996  ...         NO     13
#
# [5632 rows x 51 columns]

# %%
df.plot(kind='hist')

# %%
df.plot(kind='scatter',x='admission_type_id',y='time_in_hospital', color='red')

# %%
df.plot.area()

# %%
df.plot('race')

# %%
df.plot('gender')

# %%
##The source column indicated the compear of time in hospital and admission type. It infers the population in this hospital received attention.
##The 75% with 8.00 indicated the efficient service in its hospital. Also showing of 14.00 max in time in hospital with 8.00 max admission type the 
##results 4.00 of the comparation indicates that some patients doesn't attent there. Source column reports included Caucasian and African American
##woman with diabetes have an incidence with medicaments and continuity medical attention in this hospital.
